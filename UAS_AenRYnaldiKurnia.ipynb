# %% [markdown]
# <a href="https://colab.research.google.com/github/a22000025/Aen-rynaldi/blob/main/UAS_AenRYnaldiKurnia.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Mengambil data dari resource
data = pd.read_csv('/kebutuhan_per_bulan_2.csv')
data
# Out:
#            Propinsi  tahun kebutuhan
# 0              ACEH   2005    619876
# 1    SUMATERA UTARA   2005    547255
# 2    SUMATERA BARAT   2005    501315
# 3              RIAU   2005    551498
# 4             JAMBI   2005    495242
# ..              ...    ...       ...
# 369  SULAWESI BARAT   2015   1981507
# 370          MALUKU   2015   2197450
# 371    MALUKU UTARA   2015   2333166
# 372     PAPUA BARAT   2015   2255113
# 373           PAPUA   2015   2171944
#
# [374 rows x 3 columns]

# %%
# Filtering propinsi
data_filtered = data [data['Propinsi']=='JAWA BARAT']
data_filtered
# Out:
#        Propinsi  tahun kebutuhan
# 11   JAWA BARAT   2005    408259
# 45   JAWA BARAT   2006    542621
# 79   JAWA BARAT   2007    607425
# 113  JAWA BARAT   2008    614275
# 147  JAWA BARAT   2009    731680
# 181  JAWA BARAT   2010    743141
# 215  JAWA BARAT   2011    874693
# 249  JAWA BARAT   2012    874693
# 283  JAWA BARAT   2013    946689
# 317  JAWA BARAT   2014    946689
# 351  JAWA BARAT   2015    946689

# %%
# TABEL PERTAMA
x = data_filtered['tahun']
y = data_filtered['kebutuhan']

plt.scatter(x, y)

#add label
plt.xlabel("Tahun", fontsize = 13)
plt.ylabel("Kebutuhan" , fontsize = 13)
plt.title('Kebutuhan per bulan pada Jawa barat', fontweight ="bold",)
plt.show()

# %%
# TABEL KEDUA
y = data_filtered_jabar["kebutuhan"]
x = data_filtered_jabar["tahun"]

#Bars
plt.bar(x, y)

#line
plt.plot(x, y, 'o-', color='red')

#add label
plt.xlabel("Tahun", fontsize = 13)
plt.ylabel("Kebutuhan" , fontsize = 13)
plt.title('Kebutuhan per bulan pada Jawa Barat', fontweight ="bold",)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/SupplyKantor.csv')

data_tgl = data['TanggalPesan']
data_kota = data['Kota']
data_sales = data['SalesRep']
data_jenis = data['Jenis']
data_jum = data['Jumlah']
data_harga = data['Harga Satuan']

plt.scatter(data_tgl, data_harga, s=50, c='blue', alpha=0.7)

plt.title('Scatter Plot - Harga Satuan terhadap Tanggal Pesan')
plt.xlabel('Tanggal Pesan')
plt.ylabel('Harga Satuan')

plt.xticks(rotation=90)

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv('/content/SupplyKantor.csv')

data_tgl = data['TanggalPesan']
data_kota = data['Kota']
data_sales = data['SalesRep']
data_jenis = data['Jenis']
data_jum = data['Jumlah']
data_harga = data['Harga Satuan']

kota_unik = data_kota.unique()

colors = ['red', 'blue', 'green', 'orange']
color_mapping = {kota: colors[i % len(colors)] for i, kota in enumerate(kota_unik)}

for kota in kota_unik:
    kota_data = data[data['Kota'] == kota]
    plt.scatter(kota_data['TanggalPesan'], kota_data['Harga Satuan'], s=50, c=color_mapping[kota], alpha=0.7, label=kota)

plt.title('Scatter Plot - Harga Satuan terhadap Tanggal Pesan')
plt.xlabel('Tanggal Pesan')
plt.ylabel('Harga Satuan')

plt.legend()

plt.xticks(rotation=90)

plt.show()
